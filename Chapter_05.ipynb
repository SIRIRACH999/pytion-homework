# %% [markdown]
# # แบบฝึกหัด บทที่ 5 ตัวแปรและประเภทข้อมูล

# %%
"""
ชื่อ - สกุล - รหัส
สิริราช โทนัน 6812732125

"""

# %% [markdown]
# ## 1.	ประเภทของตัวเลขที่ภาษาไพธอนให้การรองรับมีอะไรบ้าง

# %%
"""
คำตอบ
"""

# %% [markdown]
# ## 2.จงแสดงชนิดข้อมูลของตัวแปร a และ b

# %%
"""
a = 15.50
b = ‘Python’ 
จงแสดงชนิดข้อมูลของตัวแปร a และ b
"""

# %%
"""
คำตอบ
"""
a = 15.50
b = 'Python'

print(type(a))
print(type(b))
# Out:
# <class 'float'>
# <class 'str'>

# %% [markdown]
# ## 3.จงใช้คำสั่ง print() เพื่อแสดงสตริงต่อไปนี้
#
# - Jane's teacher says "You have to study hard" –

# %%
"""
คำตอบ
"""

# %% [markdown]
# ## 4.	จงแสดงผลลัพธ์ของคำสั่งต่อไปนี้

# %%
"""
print("{2} {0} {1}".format("apple", 
         "pineapple", 
         "banana"))
"""

# %% [markdown]
# ## 5. กำหนดให้ตัวแปร

# %%
"""
pi = 3.141592653589
จงแสดงค่าของตัวแปร pi ออกทางหน้าจอให้มีทศนิยมเพียง 3 จุด
"""

# %%
"""
คำตอบ
"""
pi = 3.141592653589
print(f"{pi :.3f}")
# Out:
# 3.142

# %% [markdown]
# ## 6.กำหนดให้
# msg = "Python Programming"
#
# ให้แสดงเฉพาะ "Progra.ing"

# %%
"""
คำตอบ
"""
msg = "pytthon Programming"

print(msg[7:])
# Out:
#  Programming

# %% [markdown]
# ## 7.จงอธิบายความแตกต่างระหว่างลิสต์และทัพเพิล

# %%
"""
คำตอบ
"""

# %% [markdown]
# ## 8.การสลับค่าตัวแปร

# %%
a = 10
b= 20

a, b = b, a # สลัลค่าระหว่าง a กับ b

print("a : {} , b: {}" .format(a, b))
# Out:
# a : 20 , b: 10

# %%
a = 10
b = 20

# parall assigment
a, b = b, a

print("a : {} , b: {}".format(a, b))
# Out:
# a : 20 , b: 10

# %%
name = "flame"
last-name
